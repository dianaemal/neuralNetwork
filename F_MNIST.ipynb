# %%
from neuralNetwork import NeuralNetwork 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
nn = NeuralNetwork()

# %%
csv1 = pd.read_csv("fashion-mnist_train.csv")
images1 = csv1.iloc[:, 1:].values
labels1 = csv1.iloc[:, 0].values
print(images1.shape)
print(labels1.shape)
# Out:
# (60000, 784)
# (60000,)

# %%
# show an image from training set:
img_gray = images1[90, :].reshape(28, 28)
plt.imshow(img_gray, cmap="gray")
plt.axis("off")
plt.show()

# %%
# train 
images1 = images1 / 225.0
nn.train(images1, labels1)
# Out:
# Epoch 1, Batch 1, Iteration 1, Loss: 22.0967
# Epoch 1, Batch 1, Iteration 2, Loss: 11.3682
# Epoch 1, Batch 1, Iteration 3, Loss: 7.4702
# Epoch 1, Batch 101, Iteration 1, Loss: 1.3087
# Epoch 1, Batch 101, Iteration 2, Loss: 1.4306
# Epoch 1, Batch 101, Iteration 3, Loss: 1.4233
# Epoch 1, Batch 201, Iteration 1, Loss: 1.1987
# Epoch 1, Batch 201, Iteration 2, Loss: 1.1834
# Epoch 1, Batch 201, Iteration 3, Loss: 1.1759
# Epoch 2, Batch 1, Iteration 1, Loss: 1.2474
# Epoch 2, Batch 1, Iteration 2, Loss: 1.2592
# Epoch 2, Batch 1, Iteration 3, Loss: 1.4792
# Epoch 2, Batch 101, Iteration 1, Loss: 1.1016
# Epoch 2, Batch 101, Iteration 2, Loss: 1.2046
# Epoch 2, Batch 101, Iteration 3, Loss: 0.9791
# Epoch 2, Batch 201, Iteration 1, Loss: 0.8875
# Epoch 2, Batch 201, Iteration 2, Loss: 0.8476
# Epoch 2, Batch 201, Iteration 3, Loss: 0.8667
# Epoch 3, Batch 1, Iteration 1, Loss: 1.7178
# Epoch 3, Batch 1, Iteration 2, Loss: 1.2828
# Epoch 3, Batch 1, Iteration 3, Loss: 1.4714
# ...

# %%
# test
csv2 = pd.read_csv("fashion-mnist_test.csv")
test_images1 = csv2.iloc[:, 1:]
test_images1 = test_images1 / 225.0
print(test_images1.shape)
test_labels1 = csv2.iloc[:, 0]
print(test_labels1.shape)
# Out:
# (10000, 784)
# (10000,)

# %%
preds = nn.predict(test_images1)
acc = nn.accuracy(test_labels1, preds)
print(acc)
# Out:
# 0.8494

# %%
nn.draw_loss_curve()

# %%
nn.draw_accuracy_curve()

# %%
print(np.where(preds!= test_labels1))
# Out:
# (array([   3,    4,    5, ..., 9972, 9982, 9986]),)

# %%
test_images = csv2.iloc[:, 1:]

img_gray = np.array(test_images.iloc[9986, :]).reshape(28, 28)
print(preds[9972])
plt.imshow(img_gray, cmap="gray")
plt.axis("off")
plt.show()
# Out:
# 2
